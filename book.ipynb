# %%
# from IPython.display import display
from sympy import symbols
from numpy import linspace
from sympy import lambdify
from matplotlib.pyplot import plot, ylabel, show

def plot_func():
    t = symbols('t')
    x = 0.05*t + 0.2/((t - 5)**2 + 2)
    lam_x = lambdify(t, x, modules=['numpy'])

    x_values = linspace(0, 10, 100)
    y_values = lam_x(x_values)

    plot(x_values, y_values)
    ylabel("Speed")
    show()

def series_func():
    t = symbols('t')
    r = [2*x*t for x in range(10)]
    return r


plot_func()
series_func()
# Out:
# [0, 2⋅t, 4⋅t, 6⋅t, 8⋅t, 10⋅t, 12⋅t, 14⋅t, 16⋅t, 18⋅t]
